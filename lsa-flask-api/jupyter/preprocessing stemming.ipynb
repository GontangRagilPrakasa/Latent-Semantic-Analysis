# %%
import pandas as pd
setD = pd.read_excel('preprocessed-dataset.xlsx',sep=',')
Doc = setD['Judul'].astype('str')

# %%
pip install string
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install string
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory 
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import string

stemmer = StemmerFactory().create_stemmer()
remover = StopWordRemoverFactory().create_stop_word_remover()
translator = str.maketrans('', '', string.punctuation)

def stemmerEN(text):
    porter = PorterStemmer()
    stop = set(stopwords.words('english'))
    text = text.lower()
    text = [i for i in text.lower().split() if i not in stop]
    text = ' '.join(text)
    preprocessed_text = text.translate(translator)
    text_stem = porter.stem(preprocessed_text)
    return text_stem

def preprocess(text):
    text = text.lower()
    text_clean = remover.remove(text)
    text_stem = stemmer.stem(text_clean)
    text_stem = stemmerEN(text_stem)
    return text_stem

# %% [markdown]
# ## Judul

# %%
preprocessed_docs = []
for stemming in Doc:
    preprocessed_docs.append(preprocess(stemming))
preprocessed_docs

# %%
setD["preprocessed_judul"] = preprocessed_docs
setD
# Out:
#                                                    Judul          Reviewer  \
# 0            impact of spam exposure on user engagement.  anirban dasgupta
# 1      a real time algorithm for detection of spectac...  anirban dasgupta
# 2      clustering cookies for identifying unique mobi...  anirban dasgupta
# 3      video & eog based investigation of pure saccad...  anirban dasgupta
# 4      spam or ham?: characterizing and detecting fra...  anirban dasgupta
# 5        overcoming browser cookie churn with clustering  anirban dasgupta
# 6                         on sampling nodes in a network  anirban dasgupta
# 7      analysis of training parameters for classifier...  anirban dasgupta
# 8      an on-board vision based system for drowsiness...  anirban dasgupta
# 9      disambiguating authors in academic publication...      c. lee giles
# 10     automated alertness and emotion detection for ...  anirban dasgupta
# ...

# %%
setD.to_excel("preprocessed-dataset.xlsx", engine="xlsxwriter", index=False)
dataset = pd.read_excel("preprocessed-dataset.xlsx")
dataset
# Out:
#                                                    Judul          Reviewer  \
# 0            impact of spam exposure on user engagement.  anirban dasgupta
# 1      a real time algorithm for detection of spectac...  anirban dasgupta
# 2      clustering cookies for identifying unique mobi...  anirban dasgupta
# 3      video & eog based investigation of pure saccad...  anirban dasgupta
# 4      spam or ham?: characterizing and detecting fra...  anirban dasgupta
# 5        overcoming browser cookie churn with clustering  anirban dasgupta
# 6                         on sampling nodes in a network  anirban dasgupta
# 7      analysis of training parameters for classifier...  anirban dasgupta
# 8      an on-board vision based system for drowsiness...  anirban dasgupta
# 9      disambiguating authors in academic publication...      c. lee giles
# 10     automated alertness and emotion detection for ...  anirban dasgupta
# ...

# %% [markdown]
# ## Abstrak

# %%
preprocessed_doc = []
for stemming in setD['Abstrak']:
    preprocessed_doc.append(preprocess(stemming))
preprocessed_doc
# Out:
# ['paper quantify effect unsolicited emails spam behavior engagement email users since performing randomized experiments setting rife practical moral issues seek determine causal relationships us',
#  'eye detection plays important role many intelligent human computer interaction ihci applications eye tracking eye gaze tracking drowsiness monitoring etc however presence spectacles makes eye detection task difficult glint produced lens earlier approaches detection eyes occluded spectacles reported literature however limited accuracies paper proposes realtime algorithm detection spectacles leading detection eyes video',
# ...

# %%
setD["preprocessed_abstrak"] = preprocessed_doc
setD
# Out:
#                                                    Judul          Reviewer  \
# 0            impact of spam exposure on user engagement.  anirban dasgupta
# 1      a real time algorithm for detection of spectac...  anirban dasgupta
# 2      clustering cookies for identifying unique mobi...  anirban dasgupta
# 3      video & eog based investigation of pure saccad...  anirban dasgupta
# 4      spam or ham?: characterizing and detecting fra...  anirban dasgupta
# 5        overcoming browser cookie churn with clustering  anirban dasgupta
# 6                         on sampling nodes in a network  anirban dasgupta
# 7      analysis of training parameters for classifier...  anirban dasgupta
# 8      an on-board vision based system for drowsiness...  anirban dasgupta
# 9      disambiguating authors in academic publication...      c. lee giles
# 10     automated alertness and emotion detection for ...  anirban dasgupta
# ...

# %%
setD.to_excel("preprocessed-dataset.xlsx", engine="xlsxwriter", index=False)
dataset = pd.read_excel("preprocessed-dataset.xlsx")
dataset
# Out:
#                                                    Judul          Reviewer  \
# 0            impact of spam exposure on user engagement.  anirban dasgupta
# 1      a real time algorithm for detection of spectac...  anirban dasgupta
# 2      clustering cookies for identifying unique mobi...  anirban dasgupta
# 3      video & eog based investigation of pure saccad...  anirban dasgupta
# 4      spam or ham?: characterizing and detecting fra...  anirban dasgupta
# 5        overcoming browser cookie churn with clustering  anirban dasgupta
# 6                         on sampling nodes in a network  anirban dasgupta
# 7      analysis of training parameters for classifier...  anirban dasgupta
# 8      an on-board vision based system for drowsiness...  anirban dasgupta
# 9      disambiguating authors in academic publication...      c. lee giles
# 10     automated alertness and emotion detection for ...  anirban dasgupta
# ...
